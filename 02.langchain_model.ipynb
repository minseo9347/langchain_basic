# %% [markdown]
# # 메세지 처리방법

# %%
from dotenv import load_dotenv
import os

load_dotenv('.env', override=True)
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI


llm_gemini = ChatGoogleGenerativeAI(
    api_key=os.environ["GEMINI_API_KEY"],  # Google Gemini API 키
    model="gemini-2.0-flash",  # 또는 gemini-pro-vision 등
    temperature=0.3
)

# %%
messages = [
    [("system", "당신은 서울의 음식 전문가입니다."), ("human", "서울 광장시장에서 먹을 만한 길거리 음식들을 소개해 주세요")],
    [("system", "당신은 서울의 문화 전문가입니다."), ("human", "서울에서 데이트할 때 가 볼 만한 분위기 좋은 곳들을 알려 주세요")] 
]

responses = llm_gemini.batch(messages)
for response in responses:
    print(response.content)
    print()
# Out:
# 네, 서울 광장시장은 다양한 길거리 음식으로 유명하죠! 제가 광장시장에서 꼭 먹어봐야 할 길거리 음식들을 소개해 드릴게요.
#
# **1. 빈대떡:**
#
# *   **녹두빈대떡:** 광장시장의 대표 음식이라고 할 수 있죠. 맷돌에 갈아 만든 녹두 반죽에 돼지고기, 숙주, 고사리 등을 넣어 두툼하게 구워낸 빈대떡은 겉은 바삭하고 속은 촉촉한 식감이 일품입니다. 특히, 막걸리와 함께 먹으면 그 맛이 배가 됩니다.
# *   **고기빈대떡:** 녹두빈대떡 못지않게 인기 있는 메뉴입니다. 돼지고기를 듬뿍 넣어 더욱 고소하고 풍부한 맛을 느낄 수 있습니다.
#
# **추천 가게:** 박가네 빈대떡, 순희네 빈대떡 등
#
# **2. 마약김밥:**
#
# *   작고 앙증맞은 크기의 김밥으로, 한 번 먹으면 멈출 수 없는 중독적인 맛 때문에 '마약김밥'이라는 이름이 붙었습니다. 톡 쏘는 겨자 소스에 찍어 먹으면 더욱 맛있습니다.
#
# **추천 가게:** 모녀김밥
#
# **3. 육회:**
#
# *   신선한 육회를 저렴한 가격에 맛볼 수 있습니다. 특히, 육회와 산낙지를 함께 즐길 수 있는 '육회탕탕이'는 광장시장에서 꼭 먹어봐야 할 별미입니다.
#
# **추천 가게:** 자매집
#
# **4. 떡볶이 & 순대:**
#
# *   매콤달콤한 떡볶이와 쫄깃한 순대는 언제나 사랑받는 길거리 음식이죠. 광장시장에서는 특히 떡볶이 국물에 순대를 찍어 먹는 것이 인기입니다.
#
# **추천 가게:** 광장시장 떡볶이
#
# **5. 칼국수 & 잔치국수:**
#
# *   추운 날씨에 따뜻하게 즐기기 좋은 칼국수와 잔치국수도 빼놓을 수 없습니다. 멸치 육수의 시원한 국물과 쫄깃한 면발이 환상적인 조화를 이룹니다.
#
# **추천 가게:** 광장시장 칼국수
#
# **6. 꽈배기 & 도너츠:**
#
# *   달콤하고 쫄깃한 꽈배기와 도너츠는 남녀노소 누구나 좋아하는 간식입니다. 특히, 갓 튀겨낸 따끈한 꽈배기는 정말 꿀맛입니다.
#
# **추천 가게:** 광장시장 꽈배기
#
# **7. 호떡:**
#
# *   겨울철 대표 간식인 호떡도 광장시장에서 맛볼 수 있습니다. 달콤한 꿀이 가득한 호떡은 추위를 녹여주는 따뜻한 위로가 됩니다.
#
# **추천 가게:** 광장시장 호떡
#
# **꿀팁:**
#
# *   광장시장은 현금을 주로 사용하니, 방문 전에 현금을 준비하는 것이 좋습니다.
# *   주말에는 사람이 많으니, 평일에 방문하는 것을 추천합니다.
# *   여러 가게에서 조금씩 맛보는 재미를 느껴보세요!
#
# 광장시장에서 맛있는 길거리 음식들을 즐기며 즐거운 시간 보내시길 바랍니다!
#
# 서울에서 데이트하기 좋은 분위기 맛집들을 소개해 드릴게요. 커플의 취향에 따라 다양한 선택지가 있으니, 마음에 드는 곳을 골라 방문해 보세요!
#
# **1. 로맨틱한 야경과 함께하는 특별한 데이트**
#
# *   **N서울타워:** 서울의 랜드마크인 N서울타워는 아름다운 야경을 감상하며 로맨틱한 분위기를 만끽할 수 있는 최고의 장소입니다. 특히, 사랑의 자물쇠를 걸어 영원한 사랑을 약속하는 것은 연인들에게 인기 있는 코스입니다.
# *   **반얀트리 클럽 앤 스파 서울 문 바:** 남산에 위치한 반얀트리 문 바는 서울의 야경을 한눈에 담을 수 있는 루프탑 바입니다. 칵테일이나 와인을 즐기며 특별한 시간을 보내기에 좋습니다.
# *   **한강 유람선:** 선선한 바람을 맞으며 한강 야경을 감상하는 유람선 데이트는 잊지 못할 추억을 선사합니다. 특히, 불꽃놀이와 함께하는 유람선은 더욱 로맨틱한 분위기를 연출합니다.
#
# **2. 분위기 있는 레스토랑에서 즐기는 맛있는 데이트**
#
# *   **익선동 골목:** 한옥을 개조한 아기자기한 레스토랑과 카페들이 모여 있는 익선동은 데이트 코스로 인기가 높습니다. 다양한 분위기의 맛집에서 맛있는 음식을 즐기며 특별한 시간을 보내세요.
# *   **서촌:** 고즈넉한 분위기의 서촌은 한옥 레스토랑이나 분위기 좋은 와인바에서 데이트를 즐기기에 좋습니다. 골목길을 따라 걷다 보면 숨겨진 맛집과 카페들을 발견하는 재미도 있습니다.
# *   **가로수길:** 트렌디한 레스토랑과 카페들이 즐비한 가로수길은 세련된 분위기에서 데이트를 즐기기에 좋습니다. 맛있는 음식과 함께 쇼핑을 즐기는 것도 좋은 선택입니다.
#
# **3. 예술과 낭만이 가득한 데이트**
#
# *   **국립중앙박물관:** 다양한 전시를 관람하며 예술적인 감성을 공유하는 데이트는 어떨까요? 특히, 야간 개장 시간에는 더욱 분위기 있는 데이트를 즐길 수 있습니다.
# *   **예술의전당:** 오페라, 뮤지컬, 콘서트 등 다양한 공연을 관람하며 문화생활을 즐기는 데이트는 특별한 추억을 선사합니다. 공연 후에는 근처 레스토랑에서 식사를 즐기는 것도 좋습니다.
# *   **북촌한옥마을:** 한복을 입고 북촌한옥마을을 거닐며 사진을 찍는 데이트는 특별한 추억을 만들 수 있습니다. 한옥 카페에서 전통차를 마시며 여유로운 시간을 보내는 것도 좋습니다.
#
# **4. 활동적인 커플을 위한 이색 데이트**
#
# *   **서울숲:** 넓은 잔디밭과 아름다운 산책로가 있는 서울숲은 피크닉을 즐기거나 자전거를 타기에 좋습니다. 자연 속에서 여유로운 시간을 보내며 서로에게 집중할 수 있습니다.
# *   **한강공원:** 다양한 액티비티를 즐길 수 있는 한강공원은 활동적인 커플에게 안성맞춤입니다. 자전거를 타거나, 돗자리를 깔고 피크닉을 즐기거나, 보드 게임을 하는 등 다양한 활동을 즐길 수 있습니다.
# *   **실내 암벽등반:** 함께 땀을 흘리며 운동을 즐기는 데이트는 색다른 즐거움을 선사합니다. 서로를 응원하며 함께 목표를 달성하는 과정에서 더욱 가까워질 수 있습니다.
#
# **꿀팁:** 데이트 장소를 선택할 때에는 두 사람의 취향과 관심사를 고려하는 것이 중요합니다. 또한, 사전에 예약하거나 할인 정보를 확인하면 더욱 알뜰하게 데이트를 즐길 수 있습니다.
#
# 서울에는 이 외에도 다양한 데이트 명소들이 많으니, 두 분만의 특별한 데이트 코스를 만들어 보세요!

# %% [markdown]
# # Async vs Sync

# %%
from langchain_google_genai import ChatGoogleGenerativeAI


llm_gemini = ChatGoogleGenerativeAI(
    api_key=os.environ["GEMINI_API_KEY"],  # Google Gemini API 키
    model="gemini-2.0-flash",  # 또는 gemini-pro-vision 등
    temperature=0.3
)

messages = [
    ("system", "당신은 서울의 음시과 문화 전문가 입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
]

# %%
import asyncio
import time
# 비동기 처리 함수
async def invoke_async(llm_gemini, messages):
    response = await llm_gemini.ainvoke(messages)
    # await 키워드는 이 '대기 시간' 동안 프로그램의 제어권을 다른 작업에 넘겨줍니다. 
    # 즉, 응답을 무작정 기다리며 멈춰있는 것이 아니라 다른 코드를 실행할 수 있게 해줍니다.
    print(response.content)
# 비동기 병렬 처리 함수
async def invoke_parallel(llm_gemini, messages):
    tasks = [invoke_async(llm_gemini, messages) for _ in range(10)]
    #  계획표 10개를 만드는 것과 같다.
    await asyncio.gather(*tasks)
    # asyncio.gather는 여러 개의 비동기 작업을 동시에 실행할 수 있게 해줍니다.
    # await는 gather에 전달된 모든 작업이 완료될 때까지 기다립니다.

# %%
start = time.perf_counter()
# 병렬처리 코드
await invoke_parallel(llm_gemini, messages)
end = time.perf_counter()
print(f"병렬 처리 시간: {end - start:.2f}초")
# Out:
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 다채로운 맛을 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "밍글스" (Mingles):**
#     *   **특징:** 한식의 전통적인 요소를 현대적으로 재해석하여 창의적인 요리를 선보이는 곳입니다. 제철 식재료를 사용하여 맛과 향이 뛰어나며, 아름다운 플레이팅은 눈까지 즐겁게 합니다.
#     *   **추천 메뉴:** 런치 코스 또는 디너 코스를 통해 다양한 한식의 변주를 경험해 보세요. 특히 장 트리오 디저트는 밍글스만의 독창성을 잘 보여주는 메뉴입니다.
#     *   **분위기:** 고급스럽고 세련된 분위기에서 특별한 식사를 즐길 수 있습니다.
# 2.  **미슐랭 1스타, "주옥" (Joo Ok):**
#     *   **특징:** '음식은 곧 주옥과 같다'는 철학으로, 한국의 전통 장과 제철 식재료를 사용하여 깊은 풍미를 내는 한식 파인다이닝 레스토랑입니다.
#     *   **추천 메뉴:** 계절에 따라 바뀌는 코스 메뉴를 추천합니다. 특히, 직접 담근 장을 활용한 요리들은 주옥만의 특별함을 느낄 수 있습니다.
#     *   **분위기:** 차분하고 정갈한 분위기에서 격조 높은 식사를 즐길 수 있습니다.
# 3.  **"광장시장":**
#     *   **특징:** 100년이 넘는 역사를 자랑하는 광장시장은 서울의 대표적인 전통 시장입니다. 다양한 길거리 음식을 저렴하고 푸짐하게 즐길 수 있습니다.
#     *   **추천 메뉴:** 마약김밥, 빈대떡, 육회, 떡볶이 등 다양한 음식을 맛보세요. 특히, 따뜻한 빈대떡과 시원한 막걸리의 조합은 최고의 선택입니다.
#     *   **분위기:** 활기 넘치고 정겨운 분위기 속에서 다양한 사람들과 함께 음식을 즐길 수 있습니다.
# 4.  **"용수산":**
#     *   **특징:** 개성 음식 전문점으로, 북한 음식의 정통성을 유지하면서도 현대적인 감각을 더한 요리를 선보입니다.
#     *   **추천 메뉴:** 어복쟁반, 평양냉면, 숭어김치 등 평소에 접하기 힘든 북한 음식을 맛볼 수 있습니다.
#     *   **분위기:** 고급스럽고 차분한 분위기에서 품격 있는 식사를 즐길 수 있습니다.
# 5.  **"한국의 집":**
#     *   **특징:** 조선시대 궁중 음식의 맥을 잇는 곳으로, 전통 한옥에서 궁중 요리를 맛보며 한국의 아름다움을 느낄 수 있습니다.
#     *   **추천 메뉴:** 궁중 갈비찜, 신선로 등 궁중 요리의 진수를 경험할 수 있습니다. 전통 공연과 함께 식사를 즐길 수도 있습니다.
#     *   **분위기:** 고풍스럽고 우아한 분위기에서 특별한 경험을 할 수 있습니다.
#
# 이 외에도 서울에는 수많은 맛집들이 있습니다. 혹시 특정 음식이나 분위기를 선호하신다면, 더욱 맞춤형으로 추천해 드릴 수 있습니다.
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 다채롭게 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "밍글스" (Mingles):**
#     *   **특징:** 한식의 전통적인 요소를 현대적으로 재해석하여 창의적인 미식 경험을 선사합니다. 제철 식재료를 사용하여 맛과 향이 뛰어난 것은 물론, 플레이팅 또한 예술 작품과 같습니다.
#     *   **추천 메뉴:** 런치 및 디너 코스 (계절별 메뉴 변동)
#     *   **분위기:** 고급스럽고 세련된 분위기에서 특별한 식사를 즐길 수 있습니다.
#     *   **주소:** 서울 강남구 도산대로67길 19
# 2.  **미슐랭 1스타, "주옥" (Joo Ok):**
#     *   **특징:** 한국의 전통 장과 발효 음식을 기반으로 한 독창적인 한식 요리를 선보입니다. 슬로푸드 철학을 바탕으로 건강하고 깊은 맛을 추구합니다.
#     *   **추천 메뉴:** 런치 및 디너 코스 (계절별 메뉴 변동)
#     *   **분위기:** 정갈하고 편안한 분위기에서 한식의 깊이를 느낄 수 있습니다.
#     *   **주소:** 서울 강남구 신사동 651-3
# 3.  **"광장시장":**
#     *   **특징:** 100년이 넘는 역사를 자랑하는 전통 시장으로, 다양한 길거리 음식을 저렴하고 푸짐하게 즐길 수 있습니다.
#     *   **추천 메뉴:** 빈대떡, 마약김밥, 육회, 떡볶이, 칼국수 등
#     *   **분위기:** 활기 넘치고 정겨운 분위기 속에서 서울 시민들의 삶을 엿볼 수 있습니다.
#     *   **주소:** 서울 종로구 창경궁로 88
# 4.  **"용수산":**
#     *   **특징:** 개성 음식 전문점으로, 궁중 요리와 반가 음식을 맛볼 수 있습니다. 특히, 북한 음식인 어복쟁반과 숭어김치가 유명합니다.
#     *   **추천 메뉴:** 어복쟁반, 숭어김치, 해물전
#     *   **분위기:** 전통 한옥 스타일의 건물에서 품격 있는 식사를 즐길 수 있습니다.
#     *   **주소:** 서울 강남구 압구정로60길 39
# 5.  **"하동관":**
#     *   **특징:** 80년 이상의 역사를 자랑하는 곰탕 전문점으로, 맑고 깊은 국물 맛이 일품입니다. 오랜 시간 끓여낸 육수의 풍미를 제대로 느낄 수 있습니다.
#     *   **추천 메뉴:** 곰탕, 특곰탕
#     *   **분위기:** 소박하고 정겨운 분위기에서 곰탕 한 그릇으로 든든하게 배를 채울 수 있습니다.
#     *   **주소:** 서울 중구 명동9길 12
#
# **추가 팁:**
#
# *   미슐랭 레스토랑은 예약이 필수입니다.
# *   광장시장은 현금 결제만 가능한 곳이 많으니 현금을 준비해 가는 것이 좋습니다.
# *   각 레스토랑의 영업시간과 휴무일을 미리 확인하고 방문하세요.
#
# 이 외에도 서울에는 다양한 종류의 맛집들이 많으니, 취향에 따라 선택하여 즐거운 식도락 여행을 즐기시길 바랍니다!
# 네, 서울의 음식과 문화를 잘 아는 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 다채로운 맛을 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "권숙수":** 한식 파인 다이닝의 정수를 경험하고 싶다면 권숙수를 추천합니다. 전통 한식을 현대적으로 재해석한 창의적인 요리들을 맛볼 수 있으며, 훌륭한 서비스와 분위기는 특별한 날을 더욱 특별하게 만들어 줄 것입니다. 특히, 다양한 전통주 페어링은 음식의 풍미를 한층 더 끌어올려 줍니다.
#     *   추천 메뉴: 숙성 장, 제철 식재료를 활용한 코스 메뉴
#     *   주소: 서울 강남구 압구정로80길 37
#
# 2.  **미슐랭 1스타, "가온":** 전통 한식의 깊은 맛을 느끼고 싶다면 가온을 방문해 보세요. 옹기 발효를 통해 완성된 깊은 장맛을 기본으로, 최고의 식재료를 사용하여 정갈하고 품격 있는 한식을 선보입니다. 특히, 가온의 런치 코스는 합리적인 가격으로 훌륭한 한식을 경험할 수 있는 좋은 기회입니다.
#     *   추천 메뉴: 가온 코스, 런치 코스
#     *   주소: 서울 강남구 도산대로 317
#
# 3.  **수요미식회 선정, "황생가칼국수":** 서울의 대표적인 칼국수 맛집으로, 70년이 넘는 역사를 자랑합니다. 사골로 우려낸 깊고 진한 국물과 쫄깃한 면발의 조화가 일품이며, 특히 비 오는 날 뜨끈한 칼국수 한 그릇은 잊을 수 없는 경험을 선사합니다.
#     *   추천 메뉴: 칼국수, 사골만두
#     *   주소: 서울 종로구 소격동 84
#
# 4.  **백년가게, "이문설농탕":** 100년이 넘는 역사를 가진 설렁탕 전문점으로, 서울에서 가장 오래된 식당 중 하나입니다. 오랜 시간 끓여낸 뽀얀 국물은 깊고 담백하며, 얇게 썰어 넣은 양지 고기는 부드럽고 고소합니다. 변함없는 맛으로 오랜 시간 사랑받아온 서울의 대표적인 노포입니다.
#     *   추천 메뉴: 설렁탕, 수육
#     *   주소: 서울 종로구 견지동 88
#
# 5.  **미쉐린 빕 구르망, "만족오향족발":** 서울 3대 족발 중 하나로 꼽히는 만족오향족발은 부드럽고 쫄깃한 족발과 특제 마늘 소스의 조화가 환상적입니다. 느끼함을 잡아주는 깔끔한 맛 덕분에 많은 사람들에게 사랑받고 있으며, 특히 저녁 시간에는 웨이팅이 필수입니다.
#     *   추천 메뉴: 오향족발, 쟁반국수
#     *   주소: 서울 중구 서소문로 134-7
#
# 이 외에도 서울에는 다양한 종류의 훌륭한 음식점들이 많으니, 취향에 따라 선택하여 즐거운 미식 경험을 하시길 바랍니다.
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 제대로 경험할 수 있는 곳들입니다.
#
# 1.  **미쉐린 2스타, "밍글스"**:
#     *   **특징**: 한식의 전통적인 요소를 현대적으로 재해석하여 창의적인 요리를 선보이는 곳입니다. 제철 식재료를 사용하여 맛과 향이 뛰어나며, 아름다운 플레이팅은 눈까지 즐겁게 합니다.
#     *   **추천 메뉴**: 런치 코스 또는 디너 코스를 통해 다양한 한식의 변주를 경험해 보세요. 특히 장 트리오, 된장 크림 브륄레 등은 밍글스만의 독창적인 디저트입니다.
#     *   **분위기**: 고급스럽고 세련된 분위기에서 특별한 식사를 즐길 수 있습니다.
# 2.  **미쉐린 1스타, "주옥"**:
#     *   **특징**: '음식은 곧 주옥과 같다'라는 철학을 바탕으로, 한국의 전통 장과 제철 식재료를 사용하여 깊은 풍미를 내는 한식을 선보입니다.
#     *   **추천 메뉴**: 주옥 디너 코스를 추천합니다. 특히, 직접 담근 장으로 맛을 낸 요리들과 제철 식재료를 활용한 메뉴는 주옥의 철학을 잘 보여줍니다.
#     *   **분위기**: 차분하고 격조 높은 분위기에서 정갈한 한식을 맛볼 수 있습니다.
# 3.  **"광장시장 박가네 빈대떡"**:
#     *   **특징**: 서울의 대표적인 전통 시장인 광장시장에서 가장 유명한 빈대떡집입니다. 저렴한 가격으로 푸짐한 빈대떡을 맛볼 수 있으며, 활기 넘치는 시장 분위기를 함께 느낄 수 있습니다.
#     *   **추천 메뉴**: 녹두빈대떡과 고기완자, 막걸리를 함께 즐겨보세요.
#     *   **분위기**: 활기 넘치고 정겨운 시장 분위기 속에서 편안하게 식사를 즐길 수 있습니다.
# 4.  **"용수산"**:
#     *   **특징**: 개성 음식 전문점으로, 궁중 요리와 반가 음식의 전통을 이어가고 있습니다. 정갈하고 품격 있는 상차림과 깊은 맛은 특별한 날을 기념하기에 좋습니다.
#     *   **추천 메뉴**: 용수산 코스 메뉴를 통해 다채로운 개성 음식을 맛볼 수 있습니다. 특히, 어복쟁반과 신선로는 용수산의 대표적인 메뉴입니다.
#     *   **분위기**: 고풍스럽고 우아한 분위기에서 격조 높은 식사를 즐길 수 있습니다.
# 5.  **"하동관"**:
#     *   **특징**: 곰탕 전문점으로, 3대째 이어져 오는 깊은 역사를 자랑합니다. 맑고 깔끔한 국물과 푸짐한 양은 오랜 시간 동안 많은 사람들에게 사랑받아 왔습니다.
#     *   **추천 메뉴**: 곰탕 (보통, 특)
#     *   **분위기**: 소박하고 정겨운 분위기에서 곰탕 한 그릇을 뚝딱 비울 수 있습니다.
#
# 이 외에도 서울에는 다양한 종류의 훌륭한 한식 레스토랑들이 많습니다. 혹시 특별히 선호하는 음식 종류나 분위기가 있다면, 더 자세한 추천을 해 드릴 수 있습니다.
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 다채롭게 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "권숙수"**: 한식 파인 다이닝의 정수를 경험하고 싶다면 권숙수를 추천합니다. 전통적인 한식 조리법에 현대적인 감각을 더해 창의적인 요리를 선보입니다. 특히, 제철 식재료를 사용하여 만든 코스 메뉴는 한국의 사계절을 맛볼 수 있는 특별한 경험을 선사합니다. 격조 높은 분위기에서 특별한 날을 기념하기에 완벽한 장소입니다.
#
#     *   **추천 메뉴**: 숙성 장을 이용한 요리, 제철 식재료 코스 메뉴
#     *   **주소**: 서울 강남구 압구정로80길 37
# 2.  **미슐랭 1스타, "가온"**: 전통 한식의 깊은 맛을 느끼고 싶다면 가온을 방문해 보세요. 옹기 발효를 통해 얻은 깊은 풍미의 장과 제철 식재료를 사용하여 정갈하고 균형 잡힌 한식을 제공합니다. 특히, 가온의 런치 코스는 합리적인 가격으로 훌륭한 한식 경험을 할 수 있어 인기가 높습니다.
#
#     *   **추천 메뉴**: 가온 런치 코스, 전통 장을 이용한 요리
#     *   **주소**: 서울 강남구 도산대로 317
# 3.  **수요미식회 & 미슐랭, "황생가칼국수"**: 60년이 넘는 역사를 자랑하는 황생가칼국수는 서울 시민들의 오랜 사랑을 받아온 칼국수 전문점입니다. 사골 육수로 우려낸 깊고 진한 국물과 쫄깃한 면발의 조화가 일품입니다. 특히, 비 오는 날 따뜻한 칼국수 한 그릇은 서울의 정취를 느끼게 해줍니다.
#
#     *   **추천 메뉴**: 황생가칼국수, 해물파전
#     *   **주소**: 서울 종로구 소격동 84
# 4.  **백년가게, "이문설농탕"**: 1904년부터 4대째 이어져 오는 이문설농탕은 서울에서 가장 오래된 설렁탕 전문점입니다. 오랜 시간 푹 고아낸 뽀얀 국물은 깊고 담백한 맛을 자랑합니다. 소박하지만 정성이 가득 담긴 설렁탕 한 그릇은 서울의 역사와 문화를 느끼게 해줍니다.
#
#     *   **추천 메뉴**: 설렁탕, 수육
#     *   **주소**: 서울 종로구 견지동 88
# 5.  **골목식당 & 백종원 Pick, "에머이"**: 베트남 쌀국수 전문점이지만, 한국인의 입맛에 맞게 재해석한 쌀국수로 큰 인기를 얻고 있습니다. 특히, 깊고 진한 육수와 부드러운 면발, 풍성한 고명이 어우러진 쌀국수는 한 끼 식사로 든든합니다. 다양한 롤 메뉴와 볶음밥도 함께 즐길 수 있습니다.
#
#     *   **추천 메뉴**: 쌀국수, 넴(짜조)
#     *   **주소**: 서울 종로구 익선동 166-33
#
# 이 외에도 서울에는 수많은 맛집들이 있습니다. 혹시 특정 음식이나 분위기를 선호하신다면, 더욱 맞춤화된 추천을 해 드릴 수 있습니다. 서울에서의 맛있는 경험을 응원합니다!
# 네, 서울의 음식과 문화를 잘 아는 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 다채로운 맛을 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "밍글스" (Mingles):**
#     *   **특징:** 한식의 전통적인 요소를 현대적으로 재해석하여 창의적인 요리를 선보이는 곳입니다. 제철 식재료를 사용하여 맛과 향이 뛰어나며, 아름다운 플레이팅은 눈까지 즐겁게 합니다.
#     *   **추천 메뉴:** 런치 및 디너 코스 (계절별로 메뉴가 변경됩니다.)
#     *   **분위기:** 고급스럽고 세련된 분위기로, 특별한 날을 기념하기에 좋습니다.
#     *   **주소:** 서울 강남구 도산대로67길 19
# 2.  **미슐랭 1스타, "가온" (Gaon):**
#     *   **특징:** 한국 전통 음식의 정수를 경험할 수 있는 곳입니다. 옹기 숙성 간장, 된장, 고추장 등 전통 장류를 사용하여 깊은 풍미를 자랑합니다.
#     *   **추천 메뉴:** 가온 코스 (전통주 페어링을 추천합니다.)
#     *   **분위기:** 한국적인 아름다움이 느껴지는 공간에서 격조 높은 식사를 즐길 수 있습니다.
#     *   **주소:** 서울 강남구 도산대로317 호림아트센터 M층
# 3.  **"광장시장":**
#     *   **특징:** 서울의 대표적인 전통 시장으로, 다양한 길거리 음식을 저렴하고 푸짐하게 즐길 수 있습니다.
#     *   **추천 메뉴:** 빈대떡, 마약김밥, 육회, 떡볶이, 칼국수 등
#     *   **분위기:** 활기 넘치는 시장 분위기 속에서 다양한 먹거리를 맛보는 재미가 있습니다.
#     *   **주소:** 서울 종로구 창경궁로 88
# 4.  **"용수산":**
#     *   **특징:** 개성 음식 전문점으로, 궁중 음식과 반가 음식을 맛볼 수 있습니다. 특히, 어복쟁반과 신선로는 꼭 맛봐야 할 메뉴입니다.
#     *   **추천 메뉴:** 어복쟁반, 신선로, 구절판
#     *   **분위기:** 고풍스러운 분위기에서 품격 있는 식사를 즐길 수 있습니다.
#     *   **주소:** 서울 강남구 언주로170길 13
# 5.  **"남포면옥":**
#     *   **특징:** 60년 이상의 역사를 자랑하는 평양냉면 전문점입니다. 슴슴하면서도 깊은 육수와 메밀 향이 살아있는 면발이 일품입니다.
#     *   **추천 메뉴:** 평양냉면, 어복쟁반, 제육
#     *   **분위기:** 오랜 역사와 전통이 느껴지는 편안한 분위기입니다.
#     *   **주소:** 서울 중구 을지로5길 26
#
# 이 외에도 서울에는 수많은 맛집들이 있습니다. 혹시 특정 음식이나 분위기를 선호하신다면, 더욱 맞춤형으로 추천해 드릴 수 있습니다.
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 제대로 경험할 수 있는 곳들입니다.
#
# 1.  **미쉐린 2스타, "밍글스" (Mingles):**
#     *   **특징:** 한식의 전통적인 요소를 현대적으로 재해석하여 창의적인 요리를 선보이는 곳입니다. 제철 식재료를 사용하여 맛과 향이 뛰어나며, 아름다운 플레이팅은 눈까지 즐겁게 합니다.
#     *   **추천 메뉴:** 런치 코스, 디너 코스 (계절에 따라 메뉴가 변경됩니다.)
#     *   **분위기:** 고급스럽고 세련된 분위기로, 특별한 날을 기념하기에 좋습니다.
#     *   **주소:** 서울 강남구 도산대로67길 19
# 2.  **미쉐린 1스타, "주옥" (Joo Ok):**
#     *   **특징:** 한국의 장맛을 기반으로 한 깊은 풍미의 한식을 맛볼 수 있는 곳입니다. 전통적인 조리법을 고수하면서도 현대적인 감각을 더해 새로운 맛을 창조합니다.
#     *   **추천 메뉴:** 런치 코스, 디너 코스, 주옥 콩국수 (여름 한정)
#     *   **분위기:** 차분하고 정갈한 분위기로, 격식 있는 식사를 즐기기에 좋습니다.
#     *   **주소:** 서울 강남구 신사동 631-3
# 3.  **"광장시장":**
#     *   **특징:** 서울의 대표적인 전통 시장으로, 다양한 길거리 음식을 저렴한 가격에 맛볼 수 있습니다. 특히, 빈대떡, 마약김밥, 육회는 꼭 먹어봐야 할 메뉴입니다.
#     *   **추천 메뉴:** 빈대떡, 마약김밥, 육회, 떡볶이, 순대
#     *   **분위기:** 활기 넘치고 정겨운 분위기로, 서울 시민들의 삶을 엿볼 수 있습니다.
#     *   **주소:** 서울 종로구 창경궁로 88
# 4.  **"용수산":**
#     *   **특징:** 개성 음식을 전문으로 하는 곳으로, 궁중 음식의 맥을 잇고 있습니다. 정갈하고 품격 있는 상차림과 깊은 맛은 특별한 경험을 선사합니다.
#     *   **추천 메뉴:** 용수산 코스, 개성 탕반, 찹쌀 순대
#     *   **분위기:** 전통적인 분위기와 현대적인 감각이 조화롭게 어우러져 있습니다.
#     *   **주소:** 서울 강남구 압구정로60길 39
# 5.  **"황생가칼국수":**
#     *   **특징:** 60년 전통의 칼국수 전문점으로, 사골 육수의 깊고 진한 맛이 일품입니다. 오랜 시간 동안 변함없는 맛으로 많은 사람들에게 사랑받고 있습니다.
#     *   **추천 메뉴:** 칼국수, 왕만두, 해물파전
#     *   **분위기:** 소박하고 편안한 분위기로, 부담 없이 즐길 수 있습니다.
#     *   **주소:** 서울 종로구 소격동 84
#
# **추가 팁:**
#
# *   미쉐린 레스토랑은 예약이 필수입니다. 미리 예약하고 방문하시는 것을 추천합니다.
# *   광장시장은 현금 결제만 가능한 곳이 많으니 현금을 준비해 가시는 것이 좋습니다.
# *   각 레스토랑의 영업시간과 휴무일을 확인하고 방문하세요.
#
# 이 외에도 서울에는 훌륭한 음식점들이 많이 있습니다. 서울에서의 맛있는 경험이 즐거운 추억으로 남길 바랍니다!
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 다채롭게 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "권숙수"**: 한식 파인 다이닝의 정수를 경험하고 싶다면 권숙수를 추천합니다. 전통 한식을 현대적으로 재해석한 창의적인 요리들은 눈과 입을 모두 즐겁게 합니다. 특히, 제철 식재료를 사용하여 만든 코스 메뉴는 한국의 사계절을 맛볼 수 있는 특별한 경험을 선사합니다. 격조 높은 분위기에서 특별한 날을 기념하기에 완벽한 장소입니다.
#     *   추천 메뉴: 숙성 장 코스
#     *   주소: 서울 강남구 압구정로80길 37
#
# 2.  **미슐랭 1스타, "가온"**: 전통 한식의 깊은 맛을 느끼고 싶다면 가온을 방문해 보세요. 옹기 발효를 통해 얻은 깊은 풍미의 장을 사용하여, 섬세하고 균형 잡힌 맛을 선보입니다. 특히, 궁중 음식에서 영감을 받은 메뉴는 한국 전통 음식의 아름다움을 보여줍니다. 품격 있는 서비스와 함께 한국의 미를 경험할 수 있습니다.
#     *   추천 메뉴: 가온 코스
#     *   주소: 서울 강남구 도산대로317 호림아트센터 M층
#
# 3.  **미슐랭 1스타, "이십사절기"**: 제철 식재료의 중요성을 강조하는 이십사절기는 한국의 24절기에 맞춰 변화하는 메뉴를 제공합니다. 자연의 흐름에 따라 변화하는 식재료를 사용하여, 신선하고 건강한 요리를 맛볼 수 있습니다. 특히, 전통 조리법을 바탕으로 현대적인 감각을 더한 요리들은 미식가들의 입맛을 사로잡습니다.
#     *   추천 메뉴: 절기 코스
#     *   주소: 서울 강남구 언주로170길 37
#
# 4.  **수요미식회 선정, "황생가칼국수"**: 서울의 대표적인 서민 음식인 칼국수를 맛보고 싶다면 황생가칼국수를 추천합니다. 60년 전통의 깊은 맛을 자랑하는 이곳은 직접 뽑은 면과 진한 육수의 조화가 일품입니다. 특히, 사골 육수를 사용하여 만든 칼국수는 깊고 풍부한 맛을 선사합니다. 합리적인 가격으로 든든한 한 끼 식사를 즐길 수 있습니다.
#     *   추천 메뉴: 황생가칼국수, 해물파전
#     *   주소: 서울 종로구 소격동 84
#
# 5.  **백종원의 3대 천왕 선정, "찬양집"**: 1965년부터 이어져 온 찬양집은 서울에서 가장 오래된 칼국수 전문점 중 하나입니다. 이곳의 대표 메뉴는 푸짐한 해물과 쫄깃한 면발이 어우러진 해물칼국수입니다. 특히, 신선한 해산물을 아낌없이 사용하여 시원하고 깊은 맛을 냅니다. 저렴한 가격으로 푸짐한 양을 즐길 수 있어 오랫동안 사랑받고 있습니다.
#     *   추천 메뉴: 해물칼국수
#     *   주소: 서울 종로구 돈의동 28
#
# 이 외에도 서울에는 다양한 종류의 맛집들이 많으니, 취향에 따라 선택하여 즐거운 미식 경험을 하시길 바랍니다. 혹시 특정 종류의 음식이나 분위기를 선호하신다면, 더 자세한 추천도 가능합니다.
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 다채롭게 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "권숙수":** 한식 파인 다이닝의 정수를 경험하고 싶다면 '권숙수'를 추천합니다. 전통 한식을 현대적으로 재해석한 창의적인 요리들을 맛볼 수 있으며, 훌륭한 서비스와 분위기는 특별한 날을 더욱 특별하게 만들어 줄 것입니다. 특히, 다양한 전통주 페어링은 음식의 풍미를 한층 더 끌어올려 줍니다.
#     *   추천 메뉴: 숙성 장 맛을 느낄 수 있는 '권숙수 런치 코스' 또는 '디너 코스'
#     *   주소: 서울 강남구 압구정로80길 37
#
# 2.  **미슐랭 1스타, "가온":** '가온'은 옹기 장인이 직접 만든 그릇에 정갈하게 담겨 나오는 전통 한정식을 맛볼 수 있는 곳입니다. 궁중음식의 맥을 잇는 섬세하고 아름다운 음식들은 눈과 입을 모두 즐겁게 합니다. 격조 높은 분위기에서 중요한 손님을 접대하기에도 좋습니다.
#     *   추천 메뉴: 가온 코스
#     *   주소: 서울 강남구 도산대로 317
#
# 3.  **수요미식회 선정, "황생가칼국수":** 60년 전통의 '황생가칼국수'는 멸치와 사골로 우려낸 깊고 진한 육수가 일품입니다. 직접 담근 김치와 함께 먹는 칼국수는 추운 날씨에 몸을 녹여주는 최고의 음식이 될 것입니다. 소박하지만 변함없는 맛으로 오랫동안 사랑받아온 곳입니다.
#     *   추천 메뉴: 칼국수, 사골칼국수, 해물파전
#     *   주소: 서울 종로구 소격동 84
#
# 4.  **백종원의 3대 천왕, "찬양집":** 50년 넘게 한자리를 지켜온 '찬양집'은 푸짐한 해물칼국수로 유명합니다. 신선한 해산물이 듬뿍 들어간 칼국수는 시원하고 깊은 맛을 자랑하며, 저렴한 가격에 푸짐한 양을 즐길 수 있다는 장점이 있습니다. 허름한 외관이지만, 그 속에 담긴 맛은 결코 평범하지 않습니다.
#     *   추천 메뉴: 해물칼국수
#     *   주소: 서울 종로구 돈의동 25
#
# 5.  **미쉐린 빕 구르망, "만족오향족발":** 서울 3대 족발로 손꼽히는 '만족오향족발'은 부드럽고 촉촉한 족발과 따뜻한 떡만둣국을 함께 즐길 수 있는 곳입니다. 특제 마늘 소스에 찍어 먹는 족발은 느끼함 없이 계속 먹게 되는 마성의 맛을 자랑합니다. 퇴근 후 동료들과 함께 방문하여 푸짐하게 즐기기에 좋습니다.
#     *   추천 메뉴: 오향족발
#     *   주소: 서울 중구 서소문로 134-7
#
# 이 외에도 서울에는 수많은 맛집들이 숨어 있습니다. 혹시 특정 음식이나 분위기를 선호하신다면, 더욱 맞춤화된 추천을 해 드릴 수 있습니다. 서울에서의 맛있는 경험을 응원합니다!
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 다채롭게 경험할 수 있도록 엄선했습니다.
#
# 1.  **미슐랭 2스타, "권숙수"**: 한식 파인 다이닝의 정수를 경험하고 싶다면 권숙수를 추천합니다. 전통적인 한식을 현대적으로 재해석한 창의적인 요리들을 맛볼 수 있습니다. 특히, 제철 식재료를 사용하여 만든 코스 메뉴는 한국의 사계절을 미각으로 느낄 수 있게 해줍니다. 격조 높은 분위기에서 특별한 식사를 즐기기에 완벽한 곳입니다.
#
#     *   추천 메뉴: 숙성 장을 이용한 요리, 제철 식재료 코스 메뉴
#     *   주소: 서울 강남구 압구정로80길 37
# 2.  **미슐랭 1스타, "가온"**: 전통 한식의 깊은 맛과 아름다움을 경험할 수 있는 곳입니다. 옹기 발효를 통해 얻은 깊은 풍미의 장과 제철 식재료를 사용하여 한국의 전통적인 맛을 섬세하게 표현합니다. 특히, 가온의 런치 코스는 합리적인 가격으로 훌륭한 한식 경험을 제공합니다.
#
#     *   추천 메뉴: 런치 코스, 전통주 페어링
#     *   주소: 서울 강남구 도산대로317 호림아트센터 M층
# 3.  **백년가게, "이문설농탕"**: 1904년부터 4대째 이어져 오는 서울에서 가장 오래된 설렁탕집입니다. 뽀얀 국물에 담백한 고기가 듬뿍 들어간 설렁탕은 변함없는 맛으로 오랜 시간 동안 사랑받아 왔습니다. 소박하지만 깊은 맛을 느낄 수 있는 곳으로, 서울의 역사와 함께하는 설렁탕 한 그릇은 특별한 경험을 선사합니다.
#
#     *   추천 메뉴: 설렁탕, 수육
#     *   주소: 서울 종로구 우정국로 38-13
# 4.  **미쉐린 빕 구르망, "황생가칼국수"**: 60년 전통의 칼국수 전문점으로, 멸치와 사골로 우려낸 깊고 시원한 국물이 일품입니다. 직접 담근 김치와 함께 먹는 칼국수는 최고의 조합을 자랑합니다. 특히, 큼지막한 만두 또한 인기 메뉴입니다.
#
#     *   추천 메뉴: 칼국수, 만두
#     *   주소: 서울 종로구 소격동 84
# 5.  **종로 맛집, "광장시장"**: 다양한 길거리 음식을 한자리에서 맛볼 수 있는 광장시장은 서울의 활기찬 에너지를 느낄 수 있는 곳입니다. 마약김밥, 빈대떡, 육회 등 저렴하고 맛있는 음식을 맛보며 서울 시민들의 삶을 엿볼 수 있습니다. 특히, 주말에는 많은 사람들로 붐비니 참고하세요.
#
#     *   추천 메뉴: 마약김밥, 빈대떡, 육회
#     *   주소: 서울 종로구 창경궁로 88
#
# 이 외에도 서울에는 훌륭한 음식점들이 많으니, 여행 계획과 취향에 맞춰 다양한 맛집을 탐험해 보시길 바랍니다. 서울에서의 맛있는 경험이 즐거운 추억으로 남길 바랍니다!
# 병렬 처리 시간: 7.44초

# %%
# 동기 처리 함수 정의
def invoke_sync(messages):
    # 리스트 컨프리헨션
    res = [llm_gemini.invoke(messages) for _ in range(2)]
    for r in res:
        print(r.content)
start = time.perf_counter()
# 동기 처리 코드
invoke_sync(messages)
end = time.perf_counter()
print(f"동기 처리 시간: {end - start:.2f}초")
# Out:
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 제대로 경험할 수 있는 곳들입니다.
#
# 1.  **미슐랭 2스타, "권숙수"**: 한식 파인 다이닝의 정수를 경험하고 싶다면 '권숙수'를 추천합니다. 전통 한식을 현대적으로 재해석한 창의적인 요리들을 맛볼 수 있으며, 섬세한 서비스와 아름다운 플레이팅은 미식 경험을 한층 더 풍요롭게 만들어 줍니다. 특히, 다양한 전통주 페어링은 음식의 풍미를 더욱 깊게 느낄 수 있도록 도와줍니다.
#
#     *   추천 메뉴: 숙성 장을 이용한 요리, 제철 식재료를 활용한 코스 메뉴
#     *   주소: 서울 강남구 압구정로80길 37
# 2.  **미슐랭 1스타, "이종국104"**: 조선시대 궁중 음식의 맥을 잇는 '이종국104'는 전통 한식의 깊은 맛을 느낄 수 있는 곳입니다. 오랜 시간 정성을 들여 만든 장과 발효 음식을 사용하여, 재료 본연의 맛을 최대한 살린 요리들을 선보입니다. 고즈넉한 한옥에서 즐기는 식사는 마치 시간 여행을 하는 듯한 특별한 경험을 선사합니다.
#
#     *   추천 메뉴: 궁중 갈비찜, 전통 떡갈비
#     *   주소: 서울 종로구 북촌로 31-10
# 3.  **"용수산"**: 3대째 이어져 오는 '용수산'은 개성 음식 전문점으로, 서울에서 쉽게 접하기 힘든 독특한 향토 음식을 맛볼 수 있습니다. 특히, 톡 쏘는 맛이 일품인 '초계탕'과 다양한 채소와 고기를 얇은 밀전병에 싸 먹는 '구절판'은 용수산의 대표 메뉴입니다. 정갈하고 품격 있는 분위기에서 특별한 식사를 즐길 수 있습니다.
#
#     *   추천 메뉴: 초계탕, 구절판
#     *   주소: 서울 강남구 언주로170길 5
# 4.  **"하동관"**: 80년 이상의 역사를 자랑하는 '하동관'은 곰탕 단일 메뉴로 오랜 시간 사랑받아온 노포입니다. 맑고 깊은 국물 맛이 일품이며, 깍두기와 함께 먹으면 더욱 맛있습니다. 오랜 세월 변함없는 맛을 유지하며, 서울 시민들의 든든한 한 끼 식사를 책임져 온 곳입니다.
#
#     *   추천 메뉴: 곰탕 (보통, 특)
#     *   주소: 서울 중구 명동9길 12
# 5.  **"광장시장"**: 다양한 길거리 음식을 한자리에서 맛보고 싶다면 '광장시장'을 방문해 보세요. 빈대떡, 마약김밥, 육회 등 저렴하고 맛있는 음식을 즐길 수 있으며, 활기 넘치는 시장 분위기는 또 다른 재미를 선사합니다. 특히, 퇴근 후 동료들과 함께 방문하여 다양한 음식을 맛보며 이야기꽃을 피우는 것을 추천합니다.
#
#     *   추천 메뉴: 빈대떡, 마약김밥, 육회
#     *   주소: 서울 종로구 창경궁로 88
#
# 이 외에도 서울에는 수많은 맛집들이 숨어 있습니다. 혹시 특정 음식이나 분위기를 선호하신다면, 더욱 맞춤화된 추천을 해 드릴 수 있습니다.
# 네, 서울 음식과 문화 전문가로서 서울을 대표하는 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드립니다. 각 레스토랑은 고유한 매력과 깊은 역사를 자랑하며, 서울의 맛을 제대로 경험할 수 있는 곳들입니다.
#
# 1.  **미슐랭 2스타, "밍글스"**:
#     *   **특징**: 한식의 전통적인 요소를 현대적으로 재해석하여 창의적인 요리를 선보이는 곳입니다.
#     *   **추천 메뉴**: 제철 식재료를 사용한 코스 메뉴는 밍글스만의 독창적인 한식 경험을 선사합니다.
#     *   **분위기**: 고급스럽고 세련된 분위기에서 특별한 식사를 즐길 수 있습니다.
# 2.  **미슐랭 1스타, "주옥"**:
#     *   **특징**: 한국의 전통 장과 제철 식재료를 사용하여 깊은 풍미를 내는 한식 파인 다이닝 레스토랑입니다.
#     *   **추천 메뉴**: '주옥'의 시그니처 메뉴인 '반상'은 다양한 한식 요리를 한 번에 맛볼 수 있는 훌륭한 선택입니다.
#     *   **분위기**: 정갈하고 품격 있는 분위기에서 격조 높은 식사를 즐길 수 있습니다.
# 3.  **수요미식회 & 미슐랭 빕구르망, "황생가칼국수"**:
#     *   **특징**: 60년 전통의 깊은 맛을 자랑하는 칼국수 전문점입니다.
#     *   **추천 메뉴**: 사골로 우려낸 진한 국물의 칼국수와 시원한 맛의 콩국수는 꼭 맛봐야 할 메뉴입니다.
#     *   **분위기**: 소박하고 정겨운 분위기에서 편안하게 식사를 즐길 수 있습니다.
# 4.  **백년가게, "이문설농탕"**:
#     *   **특징**: 1904년부터 4대째 이어져 오는 서울에서 가장 오래된 설렁탕집입니다.
#     *   **추천 메뉴**: 오랜 시간 끓여낸 깊고 진한 설렁탕은 변치 않는 맛을 자랑합니다.
#     *   **분위기**: 역사와 전통이 느껴지는 공간에서 서울의 옛 맛을 경험할 수 있습니다.
# 5.  **미쉐린 빕구르망, "만족오향족발"**:
#     *   **특징**: 부드럽고 쫄깃한 족발과 특제 마늘 소스의 조화가 일품인 족발 전문점입니다.
#     *   **추천 메뉴**: 오향족발은 이곳의 대표 메뉴로, 풍부한 맛과 향을 자랑합니다.
#     *   **분위기**: 활기 넘치는 분위기에서 푸짐하고 맛있는 족발을 즐길 수 있습니다.
#
# 이 외에도 서울에는 다양한 종류의 훌륭한 한식 레스토랑들이 많으니, 취향에 따라 선택하여 서울의 맛을 즐겨보시길 바랍니다. 각 레스토랑의 위치, 영업시간, 예약 정보 등은 방문 전에 다시 한번 확인하시는 것이 좋습니다.
# 동기 처리 시간: 11.51초

# %% [markdown]
# # 대화 히스토리 지정하기
# # messages에 추가해서 해결하기

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."), 
    HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

response = llm_gemini.invoke(messages)

# %%
# 받은 응답을 messages에 추가
messages.append(response)

# %%
messages
# Out:
# [SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.', additional_kwargs={}, response_metadata={})]

# %%
# messages의 제일 마지막 요소 삭제
del messages[-1]
# messages의 제일 마지막 요소를 삭제

# %%
# messages
for message in messages:
    print(type(message), message.content)
    # print(message.content)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> 당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.
# <class 'langchain_core.messages.human.HumanMessage'> 부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.

# %% [markdown]
# # 두번째 질문과 messages에 추가하기

# %%
messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))
messages
# Out:
# [SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산역에서 그곳에 가는 교통편을 알려주세요.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산역에서 그곳에 가는 교통편을 알려주세요.', additional_kwargs={}, response_metadata={})]

# %%
# messages로 llm에 요청
response = llm_gemini.invoke(messages)

# 두번째 질문에 대한 응답을 messages에 추가
messages.append(response)

# messages 결과 확인
for message in messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 단 한 곳만 가봐야 한다면 저는 **태종대**를 추천합니다.\n\n태종대는 부산의 최남단에 위치한 곳으로, 탁 트인 바다와 기암괴석이 어우러진 아름다운 자연 경관을 자랑합니다. 특히 등대 아래 펼쳐진 몽돌해변은 파도 소리를 들으며 휴식을 취하기에 더없이 좋은 곳입니다. 유람선을 타고 해안 절경을 감상하거나, 태종대 자갈마당에서 싱싱한 해산물을 맛보는 것도 잊지 못할 경험이 될 것입니다.\n\n**부산역에서 태종대 가는 방법:**\n\n1.  **버스:** 부산역 광장에서 88번 또는 101번 버스를 타면 태종대 입구까지 한 번에 갈 수 있습니다. (약 40분 ~ 1시간 소요)\n2.  **지하철 + 버스:** 부산역에서 지하철 1호선을 타고 남포역에서 하차 후, 66번, 88번 또는 101번 버스로 환승하여 태종대 입구에서 내립니다. (총 50분 ~ 1시간 10분 소요)\n3.  **택시:** 부산역에서 택시를 타면 약 30분 정도 소요됩니다. (교통 상황에 따라 달라질 수 있습니다.)\n\n**팁:** 태종대 입구에서 등대까지는 도보로 20~30분 정도 걸리므로, 다누비 열차를 이용하는 것도 좋은 방법입니다.\n\n즐거운 부산 여행 되세요!' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--3cff6128-a006-4bcc-a479-d6df16b2ff41-0' usage_metadata={'input_tokens': 68, 'output_tokens': 401, 'total_tokens': 469, 'input_token_details': {'cache_read': 0}}

# %%
for message in messages:
    print(message)
# Out:
# content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# content='부산에서 단 한 곳만 가봐야 한다면 저는 **태종대**를 추천합니다.\n\n태종대는 부산의 최남단에 위치한 곳으로, 탁 트인 바다와 기암괴석이 어우러진 아름다운 자연 경관을 자랑합니다. 특히 등대 아래 펼쳐진 몽돌해변은 파도 소리를 들으며 휴식을 취하기에 더없이 좋은 곳입니다. 유람선을 타고 해안 절경을 감상하거나, 태종대 자갈마당에서 싱싱한 해산물을 맛보는 것도 잊지 못할 경험이 될 것입니다.\n\n**부산역에서 태종대 가는 방법:**\n\n1.  **버스:** 부산역 광장에서 88번 또는 101번 버스를 타면 태종대 입구까지 한 번에 갈 수 있습니다. (약 40분 ~ 1시간 소요)\n2.  **지하철 + 버스:** 부산역에서 지하철 1호선을 타고 남포역에서 하차 후, 66번, 88번 또는 101번 버스로 환승하여 태종대 입구에서 내립니다. (총 50분 ~ 1시간 10분 소요)\n3.  **택시:** 부산역에서 택시를 타면 약 30분 정도 소요됩니다. (교통 상황에 따라 달라질 수 있습니다.)\n\n**팁:** 태종대 입구에서 등대까지는 도보로 20~30분 정도 걸리므로, 다누비 열차를 이용하는 것도 좋은 방법입니다.\n\n즐거운 부산 여행 되세요!' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--3cff6128-a006-4bcc-a479-d6df16b2ff41-0' usage_metadata={'input_tokens': 68, 'output_tokens': 401, 'total_tokens': 469, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# # 마지막 메시지 참조

# %%
# 마지막 질문에 대한 응답 결과를 messages에서 확인하기

print(messages[-1].content)
# Out:
# 부산에서 단 한 곳만 가봐야 한다면 저는 **태종대**를 추천합니다.
#
# 태종대는 부산의 최남단에 위치한 곳으로, 탁 트인 바다와 기암괴석이 어우러진 아름다운 자연 경관을 자랑합니다. 특히 등대 아래 펼쳐진 몽돌해변은 파도 소리를 들으며 휴식을 취하기에 더없이 좋은 곳입니다. 유람선을 타고 해안 절경을 감상하거나, 태종대 자갈마당에서 싱싱한 해산물을 맛보는 것도 잊지 못할 경험이 될 것입니다.
#
# **부산역에서 태종대 가는 방법:**
#
# 1.  **버스:** 부산역 광장에서 88번 또는 101번 버스를 타면 태종대 입구까지 한 번에 갈 수 있습니다. (약 40분 ~ 1시간 소요)
# 2.  **지하철 + 버스:** 부산역에서 지하철 1호선을 타고 남포역에서 하차 후, 66번, 88번 또는 101번 버스로 환승하여 태종대 입구에서 내립니다. (총 50분 ~ 1시간 10분 소요)
# 3.  **택시:** 부산역에서 택시를 타면 약 30분 정도 소요됩니다. (교통 상황에 따라 달라질 수 있습니다.)
#
# **팁:** 태종대 입구에서 등대까지는 도보로 20~30분 정도 걸리므로, 다누비 열차를 이용하는 것도 좋은 방법입니다.
#
# 즐거운 부산 여행 되세요!

# %% [markdown]
# # 사용자 메시지 추가하고, 질문, 응답

# %%
messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요."))
response = llm_gemini.invoke(messages)
messages.append(response)
for message in messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 단 한 곳만 가봐야 한다면 저는 **태종대**를 추천합니다.\n\n태종대는 부산의 최남단에 위치한 곳으로, 탁 트인 바다와 기암괴석이 어우러진 아름다운 자연 경관을 자랑합니다. 특히 등대 아래 펼쳐진 몽돌해변은 파도 소리를 들으며 휴식을 취하기에 더없이 좋은 곳입니다. 유람선을 타고 해안 절경을 감상하거나, 태종대 자갈마당에서 싱싱한 해산물을 맛보는 것도 잊지 못할 경험이 될 것입니다.\n\n**부산역에서 태종대 가는 방법:**\n\n1.  **버스:** 부산역 광장에서 88번 또는 101번 버스를 타면 태종대 입구까지 한 번에 갈 수 있습니다. (약 40분 ~ 1시간 소요)\n2.  **지하철 + 버스:** 부산역에서 지하철 1호선을 타고 남포역에서 하차 후, 66번, 88번 또는 101번 버스로 환승하여 태종대 입구에서 내립니다. (총 50분 ~ 1시간 10분 소요)\n3.  **택시:** 부산역에서 택시를 타면 약 30분 정도 소요됩니다. (교통 상황에 따라 달라질 수 있습니다.)\n\n**팁:** 태종대 입구에서 등대까지는 도보로 20~30분 정도 걸리므로, 다누비 열차를 이용하는 것도 좋은 방법입니다.\n\n즐거운 부산 여행 되세요!' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--3cff6128-a006-4bcc-a479-d6df16b2ff41-0' usage_metadata={'input_tokens': 68, 'output_tokens': 401, 'total_tokens': 469, 'input_token_details': {'cache_read': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='그 근처에 먹을 만한 음식점들을 추천해주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='태종대 근처에는 신선한 해산물을 맛볼 수 있는 음식점들이 많습니다. 몇 군데 추천해 드릴게요.\n\n1.  **태종대 자갈마당:** 태종대 해안가에 위치한 자갈마당에서는 갓 잡아 올린 싱싱한 해산물을 맛볼 수 있습니다. 특히 해녀들이 직접 운영하는 곳에서는 더욱 신선하고 저렴하게 해산물을 즐길 수 있습니다. 멍게, 해삼, 개불, 소라 등 다양한 해산물을 맛보세요.\n\n2.  **조개구이:** 태종대 근처에는 조개구이 전문점들이 많이 있습니다. 싱싱한 조개를 연탄불에 구워 먹는 맛은 일품입니다. 특히 키조개, 가리비, 전복 등을 함께 구워 먹으면 더욱 풍성한 맛을 느낄 수 있습니다.\n\n3.  **횟집:** 태종대 주변에는 싱싱한 활어회를 맛볼 수 있는 횟집들도 많습니다. 광어, 우럭, 도다리 등 다양한 종류의 활어회를 즐길 수 있으며, 특히 바다를 바라보며 식사를 할 수 있는 곳은 더욱 특별한 경험을 선사합니다.\n\n4.  **기타:** 해산물을 즐기지 않는 분들을 위해 태종대 근처에는 칼국수, 돼지국밥, 돈까스 등 다양한 메뉴를 제공하는 음식점들도 있습니다.\n\n**몇 군데 구체적인 식당을 추천해 드릴까요?** 어떤 종류의 음식을 선호하시는지 알려주시면 더욱 자세한 정보를 드릴 수 있습니다. 예를 들어, "싱싱한 해산물을 저렴하게 먹을 수 있는 곳", "분위기 좋은 횟집", "아이와 함께 가기 좋은 곳" 등으로 말씀해 주시면 됩니다.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []} id='run--70fa22e2-8437-47fc-bc82-86b3932d9b81-0' usage_metadata={'input_tokens': 487, 'output_tokens': 470, 'total_tokens': 957, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# # langchain history 객체 이용하기
# pip install langchain_community

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", api_key=os.environ["OPENAI_API_KEY"], temperature=0.3)  # OpenAI API 키
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x110eb0ad0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11032bc20>, root_client=<openai.OpenAI object at 0x11145a990>, root_async_client=<openai.AsyncOpenAI object at 0x110eb2270>, model_name='gpt-3.5-turbo-0125', temperature=0.3, model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
from langchain.memory import ChatMessageHistory

history = ChatMessageHistory()
history.add_message(
    SystemMessage(content="당신은 서울의 음시과 문화 전문가 입니다.")
)
history.add_user_message("서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
response = llm.invoke(history.messages)

# %%
print(response)
# Out:
# content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해드리겠습니다.\n\n1. 더 코너 하우스 (The Corner House) - 한정식 전문 레스토랑으로 한국 전통 음식을 고급스러운 분위기에서 즐길 수 있습니다.\n2. 명동 칼국수 - 명동에 위치한 칼국수 전문점으로 깔끔하고 시원한 맛의 칼국수를 맛볼 수 있습니다.\n3. 미각사 (Migaksa) - 한국의 다양한 지방 음식을 한 자리에서 맛볼 수 있는 뷔페 레스토랑으로 유명합니다.\n4. 토속촌 - 전통 한식 요리를 맛볼 수 있는 레스토랑으로 한옥 분위기 속에서 한국의 맛을 경험할 수 있습니다.\n5. 더 플레이스 (The Place) - 서울 타워 근처에 위치한 레스토랑으로 한국 요리뿐만 아니라 서양 요리도 즐길 수 있습니다.\n\n이곳들을 방문하면 서울의 다양한 음식을 맛보며 한국의 다채로운 음식 문화를 경험할 수 있을 것입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 404, 'prompt_tokens': 68, 'total_tokens': 472, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BgNFYDcPtKSCKYT6pzsHdICCpJdHP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--aa3c1682-a690-4b7a-b49d-65a9e00ba62b-0' usage_metadata={'input_tokens': 68, 'output_tokens': 404, 'total_tokens': 472, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(response.content)
# Out:
# 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해드리겠습니다.
#
# 1. 더 코너 하우스 (The Corner House) - 한정식 전문 레스토랑으로 한국 전통 음식을 고급스러운 분위기에서 즐길 수 있습니다.
# 2. 명동 칼국수 - 명동에 위치한 칼국수 전문점으로 깔끔하고 시원한 맛의 칼국수를 맛볼 수 있습니다.
# 3. 미각사 (Migaksa) - 한국의 다양한 지방 음식을 한 자리에서 맛볼 수 있는 뷔페 레스토랑으로 유명합니다.
# 4. 토속촌 - 전통 한식 요리를 맛볼 수 있는 레스토랑으로 한옥 분위기 속에서 한국의 맛을 경험할 수 있습니다.
# 5. 더 플레이스 (The Place) - 서울 타워 근처에 위치한 레스토랑으로 한국 요리뿐만 아니라 서양 요리도 즐길 수 있습니다.
#
# 이곳들을 방문하면 서울의 다양한 음식을 맛보며 한국의 다채로운 음식 문화를 경험할 수 있을 것입니다.

# %%
history.add_user_message("부산역에서 그곳에 가는 교통편을 알려주세요.")
response = llm.invoke(history.messages)
history.add_ai_message(response.content)
for message in history.messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 서울의 음시과 문화 전문가 입니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 서울로 가는 교통수단은 기차, 버스, 비행기 등이 있습니다. 가장 일반적인 방법은 KTX 기차를 이용하는 것이며, 부산역에서 서울역까지 KTX 기차로 이동하는 것이 가장 빠르고 편리한 방법입니다. KTX는 매 시간마다 운행되며, 여행 시간은 약 2시간 정도 소요됩니다. 또한, 버스나 비행기를 이용하여 이동할 수도 있습니다. 부산에서 서울로 가는 버스 노선도 다양하게 운행되고 있으며, 비행기를 이용할 경우 김해공항에서 김포공항으로 이동 후 서울로 이동할 수 있습니다. 이외에도 자가용을 이용하여 고속도로를 통해 서울로 이동할 수도 있습니다. 이동 수단 선택은 여행 일정, 예산, 편의성 등을 고려하여 결정하시면 될 것 같습니다.' additional_kwargs={} response_metadata={}

# %% [markdown]
# # 토큰 수 확인하기

# %%
from langchain.callbacks import get_openai_callback
#  OpenAI 모델을 사용할 때, API 호출에 대한 토큰 사용량과 예상 비용을 손쉽게 추적하기 위한 유용한 유틸리티
with get_openai_callback() as callback:
    message = [HumanMessage(content="서울역에 도착해서 서울에서 광장시장까지 가는 교통편 3개를 알려줘")]
    reaponse = llm.invoke(message)
    print(reaponse.content)
    print("-"*20)
    print(callback)
    print("-"*20)
    print(callback.total_tokens)
# Out:
# 1. 지하철: 서울역에서 4호선을 타고 충무로역으로 이동한 뒤 환승하여 3호선을 타고 종로3가역으로 이동합니다. 걸어서 광장시장까지 도보로 이동할 수 있습니다.
#
# 2. 버스: 서울역 2번 출구에서 버스 정류장으로 이동하여 7011번 버스를 타고 종로5가 정류장에서 하차합니다. 걸어서 광장시장까지 도보로 이동할 수 있습니다.
#
# 3. 택시: 서울역에서 택시를 타고 광장시장까지 이동할 수 있습니다. 약 10~15분 정도 소요되며, 교통 상황에 따라 다를 수 있습니다.
# --------------------
# Tokens Used: 278
# 	Prompt Tokens: 51
# 		Prompt Tokens Cached: 0
# 	Completion Tokens: 227
# 		Reasoning Tokens: 0
# Successful Requests: 1
# Total Cost (USD): $0.00036600000000000006
# --------------------
# 278
